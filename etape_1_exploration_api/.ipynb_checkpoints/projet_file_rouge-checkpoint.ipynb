# %% [markdown]
# ### Récupération des données (Load des données brutes)

# %%
import requests
import json
import sys
import datetime
import time
import itertools
import pandas as pd
import seaborn as sns
import warnings
from pathlib import Path
sys.path.append(str(Path().resolve().parent))
warnings.filterwarnings("ignore")



import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.default = "notebook"   # or "notebook_connected", "jupyterlab"
sns.set()

from utils import get_data, convert_in_ms

# %%
symbols = ["BTCUSDT", "ETHUSDT", "BNBUSDT"]
intervals = ["1h", "1d"]

symbols_intervals = list(itertools.product(symbols, intervals))

# %%
for elem in symbols_intervals:
    debut = time.time()
    
    end_time = int(datetime.datetime.today().timestamp()*1000)
    
    data = get_data(*elem, start_time = 0, end_time=end_time)
    
    file_name = elem[0] + "_"+ elem[1] + ".json"
    with open(file_name, "w") as f:
        json.dump(data, f, indent=4)
        
    print(f"la durée de récupération des données : {elem[0]} avec un intervalle de {elem[1]} est : {(time.time()-debut)/60: .2f} min ")

    time.sleep(30)
# Out:
# la durée de récupération des données : BTCUSDT avec un intervalle de 1h est :  78.53 min
# la durée de récupération des données : BTCUSDT avec un intervalle de 1d est :  4.03 min
# la durée de récupération des données : ETHUSDT avec un intervalle de 1h est :  79.36 min
# la durée de récupération des données : ETHUSDT avec un intervalle de 1d est :  4.02 min
# la durée de récupération des données : BNBUSDT avec un intervalle de 1h est :  76.52 min
# la durée de récupération des données : BNBUSDT avec un intervalle de 1d est :  4.02 min
